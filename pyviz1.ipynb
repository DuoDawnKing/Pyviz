# %%
# imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20108/3311550600.py in <module>
#       2 import panel as pn
#       3 pn.extension('plotly')
# ----> 4 import plotly.express as px
#       5 import pandas as pd
#       6 import hvplot.pandas
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Read the Mapbox API key
load_dotenv()
map_box_api=("opk.eyJ1Ijoiam1maWd1ZXJvYTIiLCJhIjoiY2wyMm1temVpMGxjMzNjbzV4YmpwbzM0YyJ9.-5Ph9ZmATi8fyMlqxwq48A")
px.set_mapbox_access_token(map_box_api)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20108/203932918.py in <module>
#       1 # Read the Mapbox API key
# ----> 2 load_dotenv()
#       3 map_box_api=("opk.eyJ1Ijoiam1maWd1ZXJvYTIiLCJhIjoiY2wyMm1temVpMGxjMzNjbzV4YmpwbzM0YyJ9.-5Ph9ZmATi8fyMlqxwq48A")
#       4 px.set_mapbox_access_token(map_box_api)
#
# NameError: name 'load_dotenv' is not defined

# %%
# Import the necessary CSVs to Pandas DataFrames
# YOUR CODE HERE!
file_path = Path("sfo_neighborhoods_census_data.csv")
sfo_data = pd.read_csv(file_path, index_col="year")

file_path = Path("neighborhoods_coordinates.csv")
hood_map_df = pd.read_csv(file_path)

# %%
def housing_units_per_year(sfo_data):
    """Housing Units Per Year."""
    
    # YOUR CODE HERE!
    house_units=sfo_data.groupby('year').mean()
    house_units=house_units.drop(["sales_sqrft", "gross_rent"], axis=2)
    min=house_units.min()
    max=house_units.max()
    std=house_units.std()
    house_plot=house_units.hvplot.bar(ylim=[ave_min[0],ave_max[0]]).opts(bgcolor='white')
    return housing_plot
    
def average_gross_rent(sfo_data):
    """Average Gross Rent in San Francisco Per Year."""
    
    # YOUR CODE HERE!
    grent = sfo_data.groupby('year').mean()
    grent = grent.drop(["sale_price_sqr_foot", "housing_units"], axis=2)
    gplot = grent.hvplot.line()
    return gplot


def average_sales_price(sfo_data):
    """Average Sales Price Per Year."""
    
    # YOUR CODE HERE!
    sqr_foot = sfo_data.groupby('year').mean()
    sqr_foot = sqr_foot.drop(["housing_units", "gross_rent"], axis=1)
    sqr_plot = sqr_foot.hvplot.line()
    return sqr_plot


def average_price_by_neighborhood(sfo_data):
    """Average Prices by Neighborhood."""
    
    # YOUR CODE HERE!
    year = sfo_data.groupby(['year', 'neighborhood']).mean()
    year_plot = year['sale_price_sqr_foot'].hvplot.bar(
    title='Average Price Per Square Foot',
    xlabel= "Year",
    ylabel="housing_units",
    groupby="neighborhood")
    return area_plot


def top_most_expensive_neighborhoods(sfo_data):
    """Top 10 Most Expensive Neighborhoods."""

    # YOUR CODE HERE!


def most_expensive_neighborhoods_rent_sales(sfo_data):
    """Comparison of Rent and Sales Prices of Most Expensive Neighborhoods."""   
    
    # YOUR CODE HERE!
    top_area = sfo_data.groupby(["neighborhood"]).mean()
    top_ten_Area = expensive_area.sort_values('sale_price_sqr_foot', ascending=True).tail(10)
    top_expensive_Area = ten_exp_hood.drop(['housing_units', 'gross_rent'], axis=1)
    plot = ten_exp_plot.hvplot(kind='bar', rot=90)
    return plot
    
    
def parallel_coordinates():
    """Parallel Coordinates Plot."""

    # YOUR CODE HERE!
    mean_values = sfo_data.groupby(by='neighborhood').mean()
    mean_values = mean_values.sort_values('sale_price_sqr_foot', ascending=False).reset_index()
    hood_locations = pd.concat([hood_coor, mean_values], axis='columns', join='inner')
    area_map = px.scatter_mapbox(hood_locations,
    lat='Lat',
    lon='Lon',
    color='gross_rent',
    color_continuous_scale=px.colors.cyclical.IceFire,
    size_max=10,
    zoom=10,
    hover_name="Neighborhood",
    title="average sale price per square foot and gross rent in San Francisco")
    area_map
    return area_map


def parallel_categories():
    """Parallel Categories Plot."""
    
    # YOUR CODE HERE!



def neighborhood_map():
    """Neighborhood Map."""

    # YOUR CODE HERE!


def sunburst():
    """Sunburst Plot."""

# %%
# Create a Title for the Dashboard
# YOUR CODE HERE!
Housing = pn.Column("## Housing Units Per Year", housing_units_per_year(sfo_data), background)
GRent = pn.Column("# Average Gross Rent Per Year", average_gross_rent(sfo_data))#
Average= pn.Column("## Average Sale Price", average_sales_price(sfo_data))
Average_Pricebyhood= pn.Column("## Average Price By Neighborhood", average_price_by_neighborhood(sfo_data))
Top_Ten_Most_Expensive = pn.Column("##Top 10 Most Expensive Neighborhoods", top_most_expensive_neighborhoods(sfo_data))
Most_Expensive_Neighborhood_Rent_VS_Sale_Prices = pn.Column("## most expensive neighborhoods rent sales",
                                                            most_expensive_neighborhoods_rent_sales(sfo_data))


# Create a tab layout for the dashboard
# YOUR CODE HERE!


# Create the dashboard
# YOUR CODE HERE!
Neighborhood_Dash = pn.Tabs(("Housing Units Per Year", Housing),
                            ("Average Gross Rent in San Francisco Per Year.", GRent), 
                            ("Average Sales Price Per Year", Average),
                            ("Average Prices by Neighborhood", Average_Pricebyhood),
                            ("Top 10 Most Expensive Neighborhoods", Top_Ten_Most_Expensive), 
                            ("Comparison of Rent and Sales Prices of Most Expensive Neighborhoods", Most_Expensive_Neighborhood_Rent_VS_Sale_Prices))

# %%
 Average Housing Costs in San Francisco Per Year
In this section, you will calculate the average monthly rent and the average price per square foot for each year. An investor may wish to better understand the sales price of the rental property over time. For example, a customer will want to know if they should expect an increase or decrease in the property value over time so they can determine how long to hold the rental property.  Plot the results as two line charts.Optional challenge: Plot each line chart in a different color. In [7]:  # Calculate the average sale price per square foot and average gross rent
# YOUR CODE HERE!

# %%
# Create two line charts, one to plot the average sale price per square foot and another for average montly rent

# Line chart for average sale price per square foot
# YOUR CODE HERE!


# Line chart for average montly rent
# YOUR CODE HERE!

# %%
# Group by year and neighborhood and then create a new dataframe of the mean values
# YOUR CODE HERE!

# %%
# Use hvplot to create an interactive line chart of the average price per sq ft.
# The plot should have a dropdown selector for the neighborhood
# YOUR CODE HERE!

# %%
# Use hvplot to create an interactive line chart of the average monthly rent.
# The plot should have a dropdown selector for the neighborhood
# YOUR CODE HERE!

# %%
# Getting the data from the top 10 expensive neighborhoods to own
# YOUR CODE HERE!

# %%
 # Plotting the data from the top 10 expensive neighborhoods
# YOUR CODE HERE!

# %%
# Fetch the previously generated DataFrame that was grouped by year and neighborhood
# YOUR CODE HERE!

# %%
 # Plotting the data from the top 10 expensive neighborhoods
# YOUR CODE HERE!

# %%
 # Load neighborhoods coordinates data
# YOUR CODE HERE!

# %%
# Calculate the mean values for each neighborhood
# YOUR CODE HERE!

# %%
 # Join the average values with the neighborhood locations
# YOUR CODE HERE!

# %%
# Set the mapbox access token
# YOUR CODE HERE!

# Create a scatter mapbox to analyze neighborhood info
# YOUR CODE HERE!
